# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot([1,2,3,4])
plt.show()

# %%
x = [1,2,3,4]
y = [1,4,9,16]

plt.plot(x,y)
plt.plot(x,y,'bo')

# %%
plt.plot(y)
plt.plot(y,'r+')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot([1,2,3,4])
plt.ylabel("some numbers")
# Out:
# Text(0,0.5,'some numbers')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[1,4,9,16], 'ro')
plt.axis([0,10,0,30])
# Out:
# [0, 10, 0, 30]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.,5.,0.2)

plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
plt.savefig('plottest')

# %%
ind = np.arange(4)
y = [4,6,5,8]
plt.bar(ind,y,width=0.1,bottom=0)

plt.bar(ind,y,width=0.5,bottom=10)
# Out:
# <BarContainer object of 4 artists>

# %%
N=5
menMeans=(20,35,30,35,27)
womenMeans=(25,32,34,20,27)

ind=np.arange(N)
width=0.4

p1 = plt.bar(ind-width/2, menMeans, width, bottom=0, color='#d62728')
p2 = plt.bar(ind+width/2, womenMeans, width, bottom=5)


plt.ylabel('Scores')
plt.title('Scores by group and gendor')
plt.xticks(ind,('G1','G2','G3','G4','G5'))
plt.yticks(np.arange(0,51,5))
plt.legend((p1,p2),('Men','Women'))
plt.show()

# %%
N=5
menMeans=(20,35,30,35,27)
womenMeans=(25,32,34,20,27)

ind=np.arange(N)
width=0.5

p1 = plt.bar(ind, menMeans, width, bottom=0, color='#d62728')
p2 = plt.bar(ind, womenMeans, width, bottom=menMeans)

plt.ylabel('Scores')
plt.title('Scores by group and gendor')
plt.xticks(ind,('G1','G2','G3','G4','G5'))
plt.yticks(np.arange(0,91,10))
plt.legend((p1,p2),('Men','Women'))
plt.show()

# %%
v = np.random.uniform(0.,10.,100)
plt.hist(v)
plt.show()

# %%
v = np.random.uniform(0.,10.,200)
plt.hist(v, range=[-5.,15.], bins=100)
plt.show()

# %%
spread = np.random.rand(50) * 100   # 0~100까지 임의의 숫자
center = np.ones(25) * 50   # 50을 25개 (데이터 분포를 median에 근접하게..)
fly_high = np.random.rand(15)*100 + 100  # 100~200 범위 숫자
fly_low = np.random.rand(15)* -100   # -100~0 범위 숫자
data = np.concatenate((spread,center,fly_high, fly_low),0)

plt.boxplot(data)
plt.show()

# %%
plt.boxplot(data,1)  # median값을 강조 - notch 옵션
plt.show()

# %%
plt.boxplot(data,0,'gd')  # outlier를 green diamond로 표시
plt.show()

# %%
plt.boxplot(data,0,'')  # outlier를 표시하지 않음
plt.show()

# %%
plt.boxplot(data,0,'rs',0)  # boxplot을 가로로 표시 (4번째 parameter - vert option)
plt.show()

# %%
plt.figure()
data = [np.random.rand(50)*100, np.random.rand(50)*50]
plt.boxplot(data)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.,5.,0.1)
t2 = np.arange(0.,5.,0.2)

plt.figure(0) #chart를 그리는 평면
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')   # blue marker series + black line series 를 합쳐서 1개처럼 보이게..

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')

# %%
plt.figure(1) # chart를 그리는 평면

plt.subplot(221)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')   # 2x2 에서 좌측 상단

plt.subplot(122)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--') # 1x2에서 우측


## 이미 그려진 차트를 찾아가는 방법
plt.figure(0)
plt.subplot(211)
plt.title('easy as 1,2,3')
# Out:
# Text(0.5,1,'easy as 1,2,3')

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.,5.,0.1)
t2 = np.arange(0.,5.,0.2)

plt.figure(0) #chart를 그리는 평면
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')   # blue marker series + black line series 를 합쳐서 1개처럼 보이게..

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')

plt.figure(1) # chart를 그리는 평면

plt.subplot(221)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')   # 2x2 에서 좌측 상단

plt.subplot(122)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--') # 1x2에서 우측

## 이미 그려진 차트를 찾아가서 title을 추가함
plt.figure(0)
plt.subplot(211)
plt.title('easy as 1,2,3')

## figure내 chart를 삭제함
plt.figure(1)
plt.clf()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
## image 추가

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('plottest.png')
plt.imshow(img)

# %%
## annotation option
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)

plt.xlabel('smarts')
plt.ylabel('probability')
plt.title('Histogram')
plt.text(60, 0.025, 'this is text')
ply.axis([40,160,0,0.03])
plt.grid(True)
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-6d64d3798e1f> in <module>()
#      13 plt.title('Histogram')
#      14 plt.text(60, 0.025, 'this is text')
# ---> 15 ply.axis([40,160,0,0.03])
#      16 plt.grid(True)
#
# NameError: name 'ply' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('nyc_data.csv', parse_dates=['pickup_datetime','dropoff_datetime'])

data.head(3)
# Out:
#                           medallion                      hack_license  \
# 0  C135A2D2BCFA21DD8EB98D904824F20B  2225537D65BE958CCAF93E43C8CCDE51
# 1  DE67EF0C69802DA616A6B6C812C1C364  FF965116CF16F832F2C7F940F16746E5
# 2  4B36B70B919494AF2C9F6F96F09A1F46  0EB798058527FC155EC17BB91EF92AFC
#
#   vendor_id  rate_code store_and_fwd_flag     pickup_datetime  \
# 0       VTS          1                NaN 2013-01-15 20:09:00
# 1       VTS          1                NaN 2013-01-15 18:24:00
# 2       VTS          1                NaN 2013-01-16 19:25:00
#
#      dropoff_datetime  passenger_count  trip_time_in_secs  trip_distance  \
# 0 2013-01-15 20:17:00                2                480           1.67
# 1 2013-01-15 18:32:00                1                480           1.20
# 2 2013-01-16 19:47:00                3               1320           3.83
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# ...

# %%
data.columns

p_lng = data.pickup_longitude
p_lat = data.pickup_latitude
d_lng = data.dropoff_longitude
d_lat = data.dropoff_latitude

def lat_lng_to_pixels(lat, lng):
    lat_rad = lat * np.pi / 180.0
    lat_rad = np.log(np.tan((lat_rad+np.pi/2.0)/2.0))
    x = 100 * (lng + 180.0) / 360.0
    y = 100 * (lat_rad - np.pi) / (2.0 * np.pi)
    return (x,y)

# %%
px, py = lat_lng_to_pixels(p_lat, p_lng)
#plt.scatter(px, py)
plt.figure(figsize=(8,6))
plt.scatter(px,py,s=.1, alpha=.03)
plt.axis('equal')
plt.xlim(29.40,29.55)
plt.ylim(-37.63,-37.54)
# Out:
# (-37.63, -37.54)
